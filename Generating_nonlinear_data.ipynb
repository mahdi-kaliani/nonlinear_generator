# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return np.tan(x)

X = np.linspace(-5,5,100)
Y = np.where(f(X) >= 0,1,-1)

plt.figure()
plt.scatter(X,Y, c=Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
